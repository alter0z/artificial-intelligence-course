# %%
import numpy as np
import pandas as pd
from sklearn import svm

import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme(font_scale=1)

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 from sklearn import svm
#
# ModuleNotFoundError: No module named 'numpy'

# %%
recipes = pd.read_csv('samples.csv', sep=';')
print(recipes.head())
# Out:
#      type  flour  milk  sugar  butter  egg  baking powder  vanila  salt
# 0  muffin     35    47      9       2   36             35      27    49
# 1  muffin     14    49     31      26   19             26      16     7
# 2  muffin     24    24     29      21   38             32      44     2
# 3  muffin     15    25     42      19   27             10      31    40
# 4  muffin     44    35     26      36   32             13      23     6

# %%
sns.lmplot(x='flour', y='sugar', data=recipes, hue='type', palette='Set1', fit_reg=False, scatter_kws={'s': 70})
